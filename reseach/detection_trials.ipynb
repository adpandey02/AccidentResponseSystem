# %%
import cv2

# %%
# !conda list
# Out:
# # packages in environment at d:\projects\DL\AccidentResponseSystem\venv:
# #
# # Name                    Version                   Build  Channel
# accidentresponsesystem    0.0.0                     dev_0    <develop>
# aiofiles                  0.8.0                    pypi_0    pypi
# aiosqlite                 0.19.0                   pypi_0    pypi
# anyio                     3.7.1                    pypi_0    pypi
# argon2-cffi               23.1.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# asttokens                 2.4.1                    pypi_0    pypi
# async-lru                 2.0.4                    pypi_0    pypi
# attrs                     23.1.0                   pypi_0    pypi
# babel                     2.13.1                   pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# beautifulsoup4            4.12.2                   pypi_0    pypi
# bleach                    6.1.0                    pypi_0    pypi
# blinker                   1.7.0                    pypi_0    pypi
# ca-certificates           2023.08.22           haa95532_0
# certifi                   2022.12.7                pypi_0    pypi
# cffi                      1.16.0                   pypi_0    pypi
# chardet                   4.0.0                    pypi_0    pypi
# charset-normalizer        3.3.2                    pypi_0    pypi
# click                     8.1.7                    pypi_0    pypi
# colorama                  0.4.6                    pypi_0    pypi
# comm                      0.1.4                    pypi_0    pypi
# contourpy                 1.1.1                    pypi_0    pypi
# cycler                    0.10.0                   pypi_0    pypi
# debugpy                   1.8.0                    pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# defusedxml                0.7.1                    pypi_0    pypi
# dill                      0.3.5.1                  pypi_0    pypi
# exceptiongroup            1.1.3                    pypi_0    pypi
# executing                 2.0.1                    pypi_0    pypi
# fastjsonschema            2.18.1                   pypi_0    pypi
# filelock                  3.13.1                   pypi_0    pypi
# flask                     3.0.0                    pypi_0    pypi
# flask-cors                4.0.0                    pypi_0    pypi
# fonttools                 4.43.1                   pypi_0    pypi
# from-root                 1.0.2                    pypi_0    pypi
# fsspec                    2023.10.0                pypi_0    pypi
# gdown                     4.7.1                    pypi_0    pypi
# gitdb                     4.0.11                   pypi_0    pypi
# gitpython                 3.1.40                   pypi_0    pypi
# idna                      2.10                     pypi_0    pypi
# importlib-metadata        6.8.0                    pypi_0    pypi
# importlib-resources       6.1.0                    pypi_0    pypi
# ipykernel                 6.26.0                   pypi_0    pypi
# ipython                   8.12.3                   pypi_0    pypi
# itsdangerous              2.1.2                    pypi_0    pypi
# jedi                      0.19.1                   pypi_0    pypi
# jinja2                    3.1.2                    pypi_0    pypi
# json5                     0.9.14                   pypi_0    pypi
# jsonschema                4.19.2                   pypi_0    pypi
# jsonschema-specifications 2023.7.1                 pypi_0    pypi
# jupyter-client            8.5.0                    pypi_0    pypi
# jupyter-core              5.5.0                    pypi_0    pypi
# jupyter-lsp               2.2.0                    pypi_0    pypi
# jupyter-server            1.24.0                   pypi_0    pypi
# jupyter-server-ydoc       0.1.14                   pypi_0    pypi
# jupyter-ydoc              0.2.4                    pypi_0    pypi
# jupyterlab                4.0.0a30                 pypi_0    pypi
# jupyterlab-pygments       0.2.2                    pypi_0    pypi
# jupyterlab-server         2.25.0                   pypi_0    pypi
# kiwisolver                1.4.5                    pypi_0    pypi
# markupsafe                2.1.3                    pypi_0    pypi
# matplotlib                3.7.3                    pypi_0    pypi
# matplotlib-inline         0.1.6                    pypi_0    pypi
# mistune                   3.0.2                    pypi_0    pypi
# mpmath                    1.3.0                    pypi_0    pypi
# nbclient                  0.8.0                    pypi_0    pypi
# nbconvert                 7.10.0                   pypi_0    pypi
# nbformat                  5.9.2                    pypi_0    pypi
# nest-asyncio              1.5.8                    pypi_0    pypi
# networkx                  3.1                      pypi_0    pypi
# notebook                  7.0.0a7                  pypi_0    pypi
# notebook-shim             0.1.0                    pypi_0    pypi
# numpy                     1.24.4                   pypi_0    pypi
# opencv-contrib-python     4.8.1.78                 pypi_0    pypi
# opencv-python             4.8.1.78                 pypi_0    pypi
# opencv-python-headless    4.8.0.74                 pypi_0    pypi
# openssl                   1.1.1w               h2bbff1b_0
# packaging                 23.2                     pypi_0    pypi
# pandas                    2.0.3                    pypi_0    pypi
# pandocfilters             1.5.0                    pypi_0    pypi
# parso                     0.8.3                    pypi_0    pypi
# pickleshare               0.7.5                    pypi_0    pypi
# pillow                    10.1.0                   pypi_0    pypi
# pip                       23.3             py38haa95532_0
# pkgutil-resolve-name      1.3.10                   pypi_0    pypi
# platformdirs              3.11.0                   pypi_0    pypi
# prometheus-client         0.18.0                   pypi_0    pypi
# prompt-toolkit            3.0.39                   pypi_0    pypi
# psutil                    5.9.6                    pypi_0    pypi
# pure-eval                 0.2.2                    pypi_0    pypi
# py-cpuinfo                9.0.0                    pypi_0    pypi
# pycparser                 2.21                     pypi_0    pypi
# pygments                  2.16.1                   pypi_0    pypi
# pyparsing                 2.4.7                    pypi_0    pypi
# pysocks                   1.7.1                    pypi_0    pypi
# python                    3.8.0                hff0d562_2
# python-dateutil           2.8.2                    pypi_0    pypi
# python-dotenv             1.0.0                    pypi_0    pypi
# pytz                      2023.3.post1             pypi_0    pypi
# pywin32                   306                      pypi_0    pypi
# pywinpty                  2.0.12                   pypi_0    pypi
# pyyaml                    6.0.1                    pypi_0    pypi
# pyzmq                     25.1.1                   pypi_0    pypi
# referencing               0.30.2                   pypi_0    pypi
# requests                  2.31.0                   pypi_0    pypi
# requests-toolbelt         1.0.0                    pypi_0    pypi
# roboflow                  1.1.7                    pypi_0    pypi
# rpds-py                   0.10.6                   pypi_0    pypi
# scipy                     1.10.1                   pypi_0    pypi
# seaborn                   0.13.0                   pypi_0    pypi
# send2trash                1.8.2                    pypi_0    pypi
# setuptools                68.0.0           py38haa95532_0
# six                       1.16.0                   pypi_0    pypi
# smmap                     5.0.1                    pypi_0    pypi
# sniffio                   1.3.0                    pypi_0    pypi
# soupsieve                 2.5                      pypi_0    pypi
# sqlite                    3.41.2               h2bbff1b_0
# stack-data                0.6.3                    pypi_0    pypi
# supervision               0.16.0                   pypi_0    pypi
# sympy                     1.12                     pypi_0    pypi
# terminado                 0.17.1                   pypi_0    pypi
# thop                      0.1.1-2209072238          pypi_0    pypi
# tinycss2                  1.2.1                    pypi_0    pypi
# tomli                     2.0.1                    pypi_0    pypi
# torch                     2.1.0                    pypi_0    pypi
# torchvision               0.16.0                   pypi_0    pypi
# tornado                   6.3.3                    pypi_0    pypi
# tqdm                      4.66.1                   pypi_0    pypi
# traitlets                 5.13.0                   pypi_0    pypi
# typing-extensions         4.8.0                    pypi_0    pypi
# tzdata                    2023.3                   pypi_0    pypi
# ultralytics               8.0.203                  pypi_0    pypi
# urllib3                   2.0.7                    pypi_0    pypi
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# wcwidth                   0.2.9                    pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.6.4                    pypi_0    pypi
# werkzeug                  3.0.1                    pypi_0    pypi
# wheel                     0.41.2           py38haa95532_0
# y-py                      0.5.9                    pypi_0    pypi
# ypy-websocket             0.3.2                    pypi_0    pypi
# zipp                      3.17.0                   pypi_0    pypi

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\projects\dl\accidentresponsesystem\venv\lib\site-packages (4.8.1.78)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.17.0 in d:\projects\dl\accidentresponsesystem\venv\lib\site-packages (from opencv-python) (1.24.4)

# %%
# %pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.0 in d:\projects\dl\accidentresponsesystem\venv\lib\site-packages (from opencv-contrib-python) (1.24.4)
# Downloading opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl (44.8 MB)
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/44.8 MB 3.9 MB/s eta 0:00:12
#     --------------------------------------- 0.6/44.8 MB 6.2 MB/s eta 0:00:08
#    - -------------------------------------- 1.4/44.8 MB 10.1 MB/s eta 0:00:05
#    - -------------------------------------- 2.0/44.8 MB 10.5 MB/s eta 0:00:05
#    -- ------------------------------------- 2.5/44.8 MB 10.7 MB/s eta 0:00:04
#    -- ------------------------------------- 3.1/44.8 MB 11.0 MB/s eta 0:00:04
#    --- ------------------------------------ 3.7/44.8 MB 11.1 MB/s eta 0:00:04
#    --- ------------------------------------ 4.2/44.8 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.8/44.8 MB 11.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.4/44.8 MB 11.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.9/44.8 MB 11.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.5/44.8 MB 11.5 MB/s eta 0:00:04
#    ------ --------------------------------- 7.1/44.8 MB 11.5 MB/s eta 0:00:04
#    ------ --------------------------------- 7.6/44.8 MB 11.6 MB/s eta 0:00:04
#    ------- -------------------------------- 8.2/44.8 MB 11.6 MB/s eta 0:00:04
#    ------- -------------------------------- 8.7/44.8 MB 11.9 MB/s eta 0:00:04
#    -------- ------------------------------- 9.3/44.8 MB 11.9 MB/s eta 0:00:03
#    -------- ------------------------------- 10.1/44.8 MB 11.9 MB/s eta 0:00:03
#    --------- ------------------------------ 10.8/44.8 MB 12.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 11.4/44.8 MB 12.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 11.9/44.8 MB 12.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.5/44.8 MB 12.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 13.1/44.8 MB 12.1 MB/s eta 0:00:03
#    ------------ --------------------------- 13.6/44.8 MB 12.1 MB/s eta 0:00:03
#    ------------ --------------------------- 13.8/44.8 MB 11.9 MB/s eta 0:00:03
#    ------------ --------------------------- 13.8/44.8 MB 11.1 MB/s eta 0:00:03
#    ------------- -------------------------- 15.1/44.8 MB 11.9 MB/s eta 0:00:03
#    ------------- -------------------------- 15.6/44.8 MB 11.9 MB/s eta 0:00:03
#    -------------- ------------------------- 16.2/44.8 MB 11.9 MB/s eta 0:00:03
#    -------------- ------------------------- 16.8/44.8 MB 11.9 MB/s eta 0:00:03
#    --------------- ------------------------ 17.3/44.8 MB 11.9 MB/s eta 0:00:03
#    --------------- ------------------------ 17.9/44.8 MB 11.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.4/44.8 MB 11.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 19.0/44.8 MB 11.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.6/44.8 MB 11.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 20.1/44.8 MB 11.7 MB/s eta 0:00:03
#    ------------------ --------------------- 20.7/44.8 MB 11.7 MB/s eta 0:00:03
#    ------------------ --------------------- 21.2/44.8 MB 11.7 MB/s eta 0:00:03
#    ------------------- -------------------- 21.8/44.8 MB 11.7 MB/s eta 0:00:02
#    -------------------- ------------------- 22.4/44.8 MB 11.7 MB/s eta 0:00:02
#    -------------------- ------------------- 22.9/44.8 MB 11.7 MB/s eta 0:00:02
#    -------------------- ------------------- 23.5/44.8 MB 11.7 MB/s eta 0:00:02
#    --------------------- ------------------ 24.1/44.8 MB 13.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 24.7/44.8 MB 12.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.2/44.8 MB 12.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 25.8/44.8 MB 12.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.5/44.8 MB 12.4 MB/s eta 0:00:02
#    ------------------------ --------------- 27.3/44.8 MB 12.4 MB/s eta 0:00:02
#    ------------------------ --------------- 27.8/44.8 MB 12.3 MB/s eta 0:00:02
#    ------------------------- -------------- 28.6/44.8 MB 12.4 MB/s eta 0:00:02
#    -------------------------- ------------- 29.4/44.8 MB 12.3 MB/s eta 0:00:02
#    -------------------------- ------------- 30.0/44.8 MB 12.4 MB/s eta 0:00:02
#    --------------------------- ------------ 30.5/44.8 MB 12.1 MB/s eta 0:00:02
#    --------------------------- ------------ 31.3/44.8 MB 12.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.8/44.8 MB 12.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.4/44.8 MB 12.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.0/44.8 MB 12.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 33.5/44.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------ --------- 34.1/44.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------ --------- 34.7/44.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------- -------- 35.2/44.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------- -------- 35.8/44.8 MB 12.1 MB/s eta 0:00:01
#    -------------------------------- ------- 36.3/44.8 MB 12.1 MB/s eta 0:00:01
#    -------------------------------- ------- 36.9/44.8 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 37.5/44.8 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 38.0/44.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.6/44.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.1/44.8 MB 12.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.7/44.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------ --- 40.4/44.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------ --- 41.2/44.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 42.5/44.8 MB 12.1 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/44.8 MB 12.1 MB/s eta 0:00:01
#    -------------------------------------- - 43.6/44.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  44.2/44.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.8.1.78
# Note: you may need to restart the kernel to use updated packages.

# %%
cap = cv2.VideoCapture(0)

while True:
    success,img = cap.read()
    cv2.imshow('Image',img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
